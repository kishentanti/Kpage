# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Crime_Data_Statewise.csv')
df.head()
# Out:
#          STATE_UT       DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 0  ANDHRA PRADESH       ADILABAD  2001     101                 60
# 1  ANDHRA PRADESH      ANANTAPUR  2001     151                125
# 2  ANDHRA PRADESH       CHITTOOR  2001     101                 57
# 3  ANDHRA PRADESH       CUDDAPAH  2001      80                 53
# 4  ANDHRA PRADESH  EAST GODAVARI  2001      82                 67
#
#    CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 0                                         17    50               0
# 1                                          1    23               0
# 2                                          2    27               0
# 3                                          1    20               0
# 4                                          1    23               0
#
#    OTHER RAPE  KIDNAPPING & ABDUCTION  ...  ARSON  HURT/GREVIOUS HURT  \
# 0          50                      46  ...     30                1131
# ...

# %%
df.shape
# Out:
# (9017, 33)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9017 entries, 0 to 9016
# Data columns (total 33 columns):
# STATE_UT                                               9017 non-null object
# DISTRICT                                               9017 non-null object
# YEAR                                                   9017 non-null int64
# MURDER                                                 9017 non-null int64
# ATTEMPT TO MURDER                                      9017 non-null int64
# CULPABLE HOMICIDE NOT AMOUNTING TO MURDER              9017 non-null int64
# RAPE                                                   9017 non-null int64
# CUSTODIAL RAPE                                         9017 non-null int64
# OTHER RAPE                                             9017 non-null int64
# KIDNAPPING & ABDUCTION                                 9017 non-null int64
# KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS            9017 non-null int64
# ...

# %%
df.describe()
# Out:
#               YEAR      MURDER  ATTEMPT TO MURDER  \
# count  9017.000000  9017.00000        9017.000000
# mean   2006.629034    89.28535          78.069646
# std       3.463623   327.27503         303.446020
# min    2001.000000     0.00000           0.000000
# 25%    2004.000000    18.00000          10.000000
# 50%    2007.000000    38.00000          28.000000
# 75%    2010.000000    66.00000          56.000000
# max    2012.000000  7601.00000        7964.000000
#
#        CULPABLE HOMICIDE NOT AMOUNTING TO MURDER         RAPE  CUSTODIAL RAPE  \
# count                                9017.000000  9017.000000     9017.000000
# mean                                    9.895531    53.041366        0.005767
# std                                    59.521657   190.741450        0.115223
# min                                     0.000000     0.000000        0.000000
# 25%                                     0.000000     8.000000        0.000000
# ...

# %%
state = df.STATE_UT=='PUNJAB'
murder = df.MURDER

df [state & murder].head()
# Out:
#     STATE_UT    DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 472   PUNJAB     BARNALA  2001      15                 29
# 474   PUNJAB    BHATINDA  2001      25                 38
# 480   PUNJAB  HOSHIARPUR  2001      47                 30
# 481   PUNJAB     JAGRAON  2001      27                 33
# 484   PUNJAB      KHANNA  2001      17                 17
#
#      CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 472                                          1    12               0
# 474                                          3    13               0
# 480                                          0    19               0
# 481                                          1    19               0
# 484                                          2     6               0
#
#      OTHER RAPE  KIDNAPPING & ABDUCTION  ...  ARSON  HURT/GREVIOUS HURT  \
# 472          12                      16  ...      5                  71
# ...

# %%
state = df.STATE_UT=='PUNJAB'
year = df.YEAR==2005

df [state & year].head()
# Out:
#      STATE_UT  DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 3379   PUNJAB  AMRITSAR  2005      47                 28
# 3380   PUNJAB   BARNALA  2005      11                 12
# 3381   PUNJAB    BATALA  2005      22                 30
# 3382   PUNJAB  BHATINDA  2005      45                 52
# 3383   PUNJAB  FARIDKOT  2005      17                 36
#
#       CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 3379                                          4     5               0
# 3380                                          2    11               0
# 3381                                          1    24               0
# 3382                                         73    30               0
# 3383                                          1     6               0
#
#       OTHER RAPE  KIDNAPPING & ABDUCTION  ...  ARSON  HURT/GREVIOUS HURT  \
# 3379           5                      20  ...      0                 114
# ...

# %%
state1 = df.STATE_UT=='BIHAR'
state2 = df.STATE_UT=='PUNJAB'
year1 = df.YEAR==2011
year2 = df.YEAR==2012
rape1 = df.RAPE

# %%
df[(state1 | state2) & year1]
# Out:
#      STATE_UT          DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 7498    BIHAR            ARARIA  2011      69                 44
# 7499    BIHAR             ARWAL  2011      23                 69
# 7500    BIHAR        AURANGABAD  2011      88                105
# 7501    BIHAR            BAGAHA  2011      38                 45
# 7502    BIHAR             BANKA  2011      51                 55
# 7503    BIHAR         BEGUSARAI  2011     100                 40
# 7504    BIHAR           BETTIAH  2011      74                 12
# 7505    BIHAR           BHABHUA  2011      57                 62
# 7506    BIHAR         BHAGALPUR  2011      85                 51
# 7507    BIHAR           BHOJPUR  2011      96                 41
# 7508    BIHAR             BUXAR  2011      65                 34
# 7509    BIHAR         DARBHANGA  2011      71                 92
# 7510    BIHAR              GAYA  2011     155                 22
# ...

# %%
df[(state1 | state2) & (year1 | year2)].count()
# Out:
# STATE_UT                                               148
# DISTRICT                                               148
# YEAR                                                   148
# MURDER                                                 148
# ATTEMPT TO MURDER                                      148
# CULPABLE HOMICIDE NOT AMOUNTING TO MURDER              148
# RAPE                                                   148
# CUSTODIAL RAPE                                         148
# OTHER RAPE                                             148
# KIDNAPPING & ABDUCTION                                 148
# KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS            148
# KIDNAPPING AND ABDUCTION OF OTHERS                     148
# DACOITY                                                148
# PREPARATION AND ASSEMBLY FOR DACOITY                   148
# ROBBERY                                                148
# BURGLARY                                               148
# ...

# %%
df.head(1)
# Out:
#          STATE_UT  DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 0  ANDHRA PRADESH  ADILABAD  2001     101                 60
#
#    CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 0                                         17    50               0
#
#    OTHER RAPE  KIDNAPPING & ABDUCTION  ...  ARSON  HURT/GREVIOUS HURT  \
# 0          50                      46  ...     30                1131
#
#    DOWRY DEATHS  ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY  \
# 0            16                                                149
#
#    INSULT TO MODESTY OF WOMEN  CRUELTY BY HUSBAND OR HIS RELATIVES  \
# 0                          34                                  175
#
#    IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES  CAUSING DEATH BY NEGLIGENCE  \
# 0                                            0                          181
#
#    OTHER IPC CRIMES  TOTAL IPC CRIMES
# 0              1518              4154
#
# [1 rows x 33 columns]

# %%
#PUNJAB DATA
abc = df.loc[ :, ['STATE_UT', 'DISTRICT','YEAR','MURDER']]

abc[abc.STATE_UT=='PUNJAB']

#def1 = (abc.STATE_UT=='PUNJAB') & (abc.MURDER)

pb = abc.STATE_UT=='PUNJAB'
md = abc.MURDER

dl = abc[pb & md]

# %%
#Maximum murder in Punjab
pb = abc.STATE_UT=='PUNJAB'
mr = abc.MURDER==max(ds.MURDER)

abc[pb & mr]
# Out:
#      STATE_UT DISTRICT  YEAR  MURDER
# 7175   PUNJAB    TOTAL  2010     907

# %%
#Minimum murder in Punjab
min_mur = ds.MURDER==min(ds.MURDER)

abc[pb & min_mur]
# Out:
#      STATE_UT DISTRICT  YEAR  MURDER
# 1195   PUNJAB    G.R.P  2002       5
# 3386   PUNJAB    G.R.P  2005       5
# 8746   PUNJAB    G.R.P  2012       5

# %%
#Maximum murder in Punjab
hr = abc[abc.STATE_UT=='HARYANA']

hr_b = abc.STATE_UT=='HARYANA'
mr = (hr.MURDER==max(hr.MURDER))

hr[hr_b & mr]
# Out:
# c:\users\deepa\appdata\local\programs\python\python36-32\lib\site-packages\ipykernel_launcher.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   import sys
#      STATE_UT DISTRICT  YEAR  MURDER
# 7626  HARYANA    TOTAL  2011    1062

# %%
#Minimum murder in Punjab
hr = abc[abc.STATE_UT=='HARYANA']

hr_b = abc.STATE_UT=='HARYANA'
mr = (hr.MURDER==min(hr.MURDER))

hr[hr_b & mr]
# Out:
# c:\users\deepa\appdata\local\programs\python\python36-32\lib\site-packages\ipykernel_launcher.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   import sys
#      STATE_UT   DISTRICT  YEAR  MURDER
# 899   HARYANA  PANCHKULA  2002       7
# 2350  HARYANA  PANCHKULA  2004       7

# %%
#Minimum murder in Punjab
bh = abc[abc.STATE_UT=='BIHAR']

bh_b = abc.STATE_UT=='BIHAR'
mr1 = (bh.MURDER==min(bh.MURDER))
bh[bh_b & mr1]
# Out:
# c:\users\deepa\appdata\local\programs\python\python36-32\lib\site-packages\ipykernel_launcher.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#      STATE_UT       DISTRICT  YEAR  MURDER
# 6733    BIHAR  JAMALPUR RLY.  2010       3

# %%
#Maximum murder in Punjab
bh = abc[abc.STATE_UT=='BIHAR']

bh_b = abc.STATE_UT=='BIHAR'
mr1 = (bh.MURDER==max(bh.MURDER))
bh[bh_b & mr1]
# Out:
# c:\users\deepa\appdata\local\programs\python\python36-32\lib\site-packages\ipykernel_launcher.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#      STATE_UT DISTRICT  YEAR  MURDER
# 2281    BIHAR    TOTAL  2004    3948

# %%
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 8987    False
# 8988    False
# 8989    False
# 8990    False
# 8991    False
# 8992    False
# 8993    False
# 8994    False
# 8995    False
# 8996    False
# 8997    False
# 8998    False
# 8999    False
# 9000    False
# 9001    False
# 9002    False
# 9003    False
# 9004    False
# 9005    False
# 9006    False
# 9007    False
# 9008    False
# 9009    False
# 9010    False
# 9011    False
# 9012    False
# 9013    False
# 9014    False
# 9015    False
# 9016    False
# ...
